# %%
import pandas as pd
from requests_html2 import HTMLSession
session = HTMLSession()

# %%
headers = {
    "Accept": "application/json, text/plain, */*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "zh-CN,zh;q=0.9",
    "Cookie": "lastCity=101280100; wd_guid=6d94fbd6-1540-49ea-994c-55cff058429a; historyState=state; _bl_uid=qdlmXnt6y580zjlUL218jC8gtdIC; wt2=D83M1xYD4znd1WulaHeESjNGspOfjfVmjHG1jmvM-427OwUJfKCB3x4BAKg4SawxZJk5woA2nI_ATazOLC9BnDw~~; wbg=0; Hm_lvt_194df3105ad7148dcf2b98a91b5e727a=1700923091,1701255767,1701316660; collection_pop_window=1; __zp_seo_uuid__=da44edb0-d991-4755-9be8-d51981ac90c0; __g=-; __c=1701316660; __l=r=https%3A%2F%2Fcn.bing.com%2F&l=%2Fwww.zhipin.com%2Fjob_detail%2F6b603e522ab8cab41XJ52921FlFX.html%3Flid%3D6ERYnNga7Gc.search.1%26securityId%3D6otBTWSyLmsrF-d1tTZLfHj22tBwJEMBeA3iveCb2kCCWm9zqqv8KW1DIlVZpWuDhOAjdQ8Q81a7itfptKcfV-E0NerR6sQQUE0ZHgNO3kwLu9fMvG53SL8ETxU1GFUwE3hm6S-FG8MMyIs3J71qvvU4kv2vE0GEQ-G2J-Yy0tufn-A~%26sessionId%3D&s=3&g=&friend_source=0&s=3&friend_source=0; __a=17707652.1697770260.1701255767.1701316660.37.5.8.8; __zp_stoken__=%2FDtsSYwpRMwp3CrsOBwpjCjVXCp1bDukfCrmdHV8KxcsKUa8K%2FwrrCnFXCvcK9wqrCvsKrwrZIw4DCqMK%2FSMK5w4FPdXBrYmtlDAcOV1k6C1AHw4c%3D; Hm_lpvt_194df3105ad7148dcf2b98a91b5e727a=1701342666; geek_zp_token=V1RNkiEub_315vVtRuzxwbLSy45T7fxiQ~",
    "Referer": "https://www.zhipin.com/web/geek/job?query=%E5%B9%BF%E5%91%8A%E7%AD%96%E5%88%92&city=101280100",
    "Sec-Ch-Ua": "\"Google Chrome\";v=\"119\", \"Chromium\";v=\"119\", \"Not?A_Brand\";v=\"24\"",
    "Sec-Ch-Ua-Mobile": "?0",
    "Sec-Ch-Ua-Platform": "\"Windows\"",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "Token": "UhWt5bI9kvhA22kj",
    "Traceid": "B66EDA71-C197-4983-8B47-413DF1D3EE28",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
    "X-Requested-With": "XMLHttpRequest",
    "Zp_token": "V1RNkiEub_315vVtRuzxwbLSy45T7fxiQ~"
}

# %%
cities={
    '北京':'101010100',
    '上海':'101020100',
    '广州':'101280100',
    '深圳':'101280600'
}

# %%
def get_cities(city):
    return cities[str(city)]

# %%
关键词 = input("输入职位关键词")

# %%
城市 = input("输入城市，目前支持北京、上海、广州、深圳")

# %%
import urllib.parse
encoded_content = urllib.parse.quote(str(关键词))
print(encoded_content)
# Out:
# %E5%B9%BF%E5%91%8A%E7%AD%96%E5%88%92

# %%
from requests_html import AsyncHTMLSession
asession = AsyncHTMLSession()
r = await asession.get('https://www.zhipin.com/wapi/zpgeek/search/joblist.json?scene=1&query='+str(encoded_content)+'&city='+str(get_cities(城市))+'&experience=&payType=&partTime=&degree=&industry=&scale=&stage=&position=&jobType=&salary=&multiBusinessDistrict=&multiSubway=&page=1&pageSize=30',headers=headers)

# %%
r
# Out:
# <Response [200]>

# %%
response_data = r.json()
response_data
# Out:
# {'code': 0,
#  'message': 'Success',
#  'zpData': {'resCount': 450,
#   'filterString': '',
#   'lid': '6h3r5eM2hoA',
#   'hasMore': True,
#   'jobList': [{'securityId': '3qsJFh-EfCDVZ-O1FwHF6CgiZSmJ5VnY4c77CFJc4913spQH1mxSYKrMtuwScfIjhynF_rSkW6fcJNjzh4zjuaMPlTJOkQMlhVZpF-rq4TVzbSoNBIDv_pGyxcrCtjFwgGlqmC07ot2BBWOBocAhdeRk0zX78rrTveeHHaKrG0RYzUiCQw~~',
#     'bossAvatar': 'https://img.bosszhipin.com/beijin/upload/avatar/20230426/607f1f3d68754fd025d6706ca2db41a4198269456ea9cd106bc2d4c053e952383916819920a9f64c_s.png',
#     'bossCert': 3,
#     'encryptBossId': '0fee4c55e1102d1e0n1_29m5GVRY',
#     'bossName': '魏子钧',
#     'bossTitle': 'Hr',
#     'goldHunter': 0,
#     'bossOnline': True,
#     'encryptJobId': '27a454904eafd2c51HVy3968FFFX',
#     'expectId': 259072637,
#     'jobName': '广告策划（实习生、应届生、有经验者均可）',
#     'lid': '6h3r5eM2hoA.search.1',
#     'salaryDesc': '6-11K',
#     'jobLabels': ['经验不限', '本科'],
#     'jobValidStatus': 1,
#     'iconWord': '',
# ...

# %%
import pandas as pd

# %%
df_boss = pd.json_normalize(response_data['zpData']['jobList'])
df_boss
# Out:
#                                            securityId  \
# 0   3qsJFh-EfCDVZ-O1FwHF6CgiZSmJ5VnY4c77CFJc4913sp...
# 1   T2BuiC3HIXwLa-A1oX79gxEdeOP7RlDJL7G9iNj54hD3G9...
# 2   svnQCWO20Xbxv-u16uuTpJab0Zav_AzYqZCfE4f-1ZNMQm...
# 3   5HFzjewox7k90-G1C1XMX5TH6b_FFoNK8Z-YZzMALeadG_...
# 4   xcygccKJO4vmE-31rgveutlo-FTMTAPCCr3_cJQzJVBGT5...
# 5   Q6k0obuXVjej_-K1QNax25xEkwtUdVhfX7us62-U4URheQ...
# 6   f6nj5jU5IY6No-11Rcch3C3q08KozCrwjnLcr5Ii0_oZr5...
# 7   dqtb7WuK0xFhe-d1ExCfqeuBdhJLXPC0l1I2XSMmk5QTJU...
# 8   2l5pn4nHPDrNS-518v0z7iHETjhMca_hUjj09cio7xZ9UJ...
# 9   a5p0C84PBFQVK-T1ZjM7aaaMYfsACM2zi1IYyLhBmRFCQc...
# 10  ZRKbicdo0l991-D1yI_5Bd0cWKjsux7oZUNeZDla4GU2pe...
# 11  jorBkt2zeGjeQ-x1hbAFZlD3UeowB3V5wEqtf0DTuOoYGE...
# 12  Ur9jxOpJsIOEL-E1JPZ32RFrbcKt7t5ypsay6ReHbreVDw...
# 13  TTwMnxxS41HlC-91PsdLg2AjAgibZsIHZ1-V3DXuFXY_5x...
# 14  2Aeq3Pqif3rs2-W1aEbGJUkzamYN9iL41ndiz8SD0BS2k6...
# 15  Y5w6n0AGGYjMH-r133croF2OiWXMFDjdv5oEzntl0Ov2gx...
# ...

# %%
df_boss.to_excel('boss直聘-测试.xlsx')

# %%
read_boss = pd.read_excel('boss直聘-测试.xlsx')
read_boss
# Out:
#     Unnamed: 0                                         securityId  \
# 0            0  3qsJFh-EfCDVZ-O1FwHF6CgiZSmJ5VnY4c77CFJc4913sp...
# 1            1  T2BuiC3HIXwLa-A1oX79gxEdeOP7RlDJL7G9iNj54hD3G9...
# 2            2  svnQCWO20Xbxv-u16uuTpJab0Zav_AzYqZCfE4f-1ZNMQm...
# 3            3  5HFzjewox7k90-G1C1XMX5TH6b_FFoNK8Z-YZzMALeadG_...
# 4            4  xcygccKJO4vmE-31rgveutlo-FTMTAPCCr3_cJQzJVBGT5...
# 5            5  Q6k0obuXVjej_-K1QNax25xEkwtUdVhfX7us62-U4URheQ...
# 6            6  f6nj5jU5IY6No-11Rcch3C3q08KozCrwjnLcr5Ii0_oZr5...
# 7            7  dqtb7WuK0xFhe-d1ExCfqeuBdhJLXPC0l1I2XSMmk5QTJU...
# 8            8  2l5pn4nHPDrNS-518v0z7iHETjhMca_hUjj09cio7xZ9UJ...
# 9            9  a5p0C84PBFQVK-T1ZjM7aaaMYfsACM2zi1IYyLhBmRFCQc...
# 10          10  ZRKbicdo0l991-D1yI_5Bd0cWKjsux7oZUNeZDla4GU2pe...
# 11          11  jorBkt2zeGjeQ-x1hbAFZlD3UeowB3V5wEqtf0DTuOoYGE...
# 12          12  Ur9jxOpJsIOEL-E1JPZ32RFrbcKt7t5ypsay6ReHbreVDw...
# ...

# %%
df_boss_zp = read_boss[['jobName','jobLabels','salaryDesc','welfareList','jobDegree','cityName','areaDistrict','brandName','brandIndustry','brandScaleName','skills','lid','securityId','encryptJobId']]

# %%
df_boss_zp
# Out:
#                  jobName              jobLabels  salaryDesc  \
# 0   广告策划（实习生、应届生、有经验者均可）         ['经验不限', '本科']       6-11K
# 1                 广告策划助理  ['5天/周', '3个月', '本科']  230-280元/天
# 2                广告策划-快消         ['3-5年', '本科']  25-50K·16薪
# 3               游戏广告创意策划         ['经验不限', '本科']      15-30K
# 4                   广告策划         ['1-3年', '本科']      15-25K
# 5             B站广告策划（食饮）         ['3-5年', '本科']  15-30K·15薪
# 6         广告创意策划【可接受应届生】         ['经验不限', '本科']      10-14K
# 7            广告策划-豪华汽车方向         ['3-5年', '本科']  15-30K·15薪
# 8          商业广告策划 J68417         ['1-3年', '本科']  15-30K·16薪
# 9                 广告创意策划         ['1年以内', '本科']      11-20K
# 10                广告创意策划       ['经验不限', '学历不限']      13-20K
# 11        品牌广告策划(J10606)         ['1-3年', '本科']  15-30K·14薪
# 12                广告创意策划       ['3-5年', '学历不限']      10-15K
# 13                广告策划专员         ['1-3年', '本科']      12-20K
# 14          营销策划岗位（亚太区域）       ['经验不限', '学历不限']  30-50K·15薪
# ...

# %%
df_boss_zp = df_boss_zp.rename(columns={
    'jobName':'职位名称',
    'jobLabels':'公司标签',
    'salaryDesc':'工资水平',
    'welfareList':'公司福利',
    'jobDegree':'学历要求',
    'cityName':'公司所在城市',
    'areaDistrict':'公司街道',
    'brandName':'公司名称',
    'brandIndustry':'公司行业',
    'brandScaleName':'公司规模',
    'skills':'技能要求',
    'lid':'标准库号',
    'securityId':'安全码',
    'encryptJobId':'岗位ID号'
})

# %%
df_boss_zp
# Out:
#                     职位名称                   公司标签        工资水平  \
# 0   广告策划（实习生、应届生、有经验者均可）         ['经验不限', '本科']       6-11K
# 1                 广告策划助理  ['5天/周', '3个月', '本科']  230-280元/天
# 2                广告策划-快消         ['3-5年', '本科']  25-50K·16薪
# 3               游戏广告创意策划         ['经验不限', '本科']      15-30K
# 4                   广告策划         ['1-3年', '本科']      15-25K
# 5             B站广告策划（食饮）         ['3-5年', '本科']  15-30K·15薪
# 6         广告创意策划【可接受应届生】         ['经验不限', '本科']      10-14K
# 7            广告策划-豪华汽车方向         ['3-5年', '本科']  15-30K·15薪
# 8          商业广告策划 J68417         ['1-3年', '本科']  15-30K·16薪
# 9                 广告创意策划         ['1年以内', '本科']      11-20K
# 10                广告创意策划       ['经验不限', '学历不限']      13-20K
# 11        品牌广告策划(J10606)         ['1-3年', '本科']  15-30K·14薪
# 12                广告创意策划       ['3-5年', '学历不限']      10-15K
# 13                广告策划专员         ['1-3年', '本科']      12-20K
# 14          营销策划岗位（亚太区域）       ['经验不限', '学历不限']  30-50K·15薪
# ...

# %% [markdown]
# # 拿到岗位详情链接

# %%
岗位详情页URL = []
for i in range(len(df_boss['jobName'])):
    url = 'https://www.zhipin.com/job_detail/'+str(df_boss['encryptJobId'][i])+'.html?lid='+str(df_boss['lid'][i])+'&securityId='+str(df_boss['securityId'][i])+'&sessionId='
    岗位详情页URL.append(url)

# %%
岗位详情页URL
# Out:
# ['https://www.zhipin.com/job_detail/27a454904eafd2c51HVy3968FFFX.html?lid=6h3r5eM2hoA.search.1&securityId=3qsJFh-EfCDVZ-O1FwHF6CgiZSmJ5VnY4c77CFJc4913spQH1mxSYKrMtuwScfIjhynF_rSkW6fcJNjzh4zjuaMPlTJOkQMlhVZpF-rq4TVzbSoNBIDv_pGyxcrCtjFwgGlqmC07ot2BBWOBocAhdeRk0zX78rrTveeHHaKrG0RYzUiCQw~~&sessionId=',
#  'https://www.zhipin.com/job_detail/9316b44e56a7fc4b1HZ70926F1NT.html?lid=6h3r5eM2hoA.search.2&securityId=T2BuiC3HIXwLa-A1oX79gxEdeOP7RlDJL7G9iNj54hD3G9YGHW1szffzFDd2EXG2cwD0hxb_qfRNhfVR8nVOWQ9ux0XJ6XeZkyb46Oo5B52gREbr7Uw4m2GGoevCqw8XCbC87ahJTgXKa2BePLc81jqdrNcekT_IwBrywiHE2Es-8A~~&sessionId=',
#  'https://www.zhipin.com/job_detail/3b446c17288155c01HZ70tu5FVdV.html?lid=6h3r5eM2hoA.search.3&securityId=svnQCWO20Xbxv-u16uuTpJab0Zav_AzYqZCfE4f-1ZNMQm5oLkyeitmv76OHQTIZq2HQEKS8MQjnUrss4l10QL3oV-ufrnTzO8JwOPPyvNMWOjuJmVNp3ffWQpGXwfXa2ac93uu7vXjsDpOFfg_-3Lqf26EYWYU6NMvcVdWOsKHFHr_h&sessionId=',
# ...

# %%
import time
time.localtime()
output_time = str(time.localtime().tm_year)+'-'\
              +str(time.localtime().tm_mon)+'-'\
             +str(time.localtime().tm_mday)+'_'\
             +str(time.localtime().tm_hour)+'-' \
             +str(time.localtime().tm_min)
output_time

# %%
df_boss_zp.to_excel('boss直聘'+str(城市)+'-'+str(关键词)+'求职数据'+output_time+'.xlsx')

# %%
岗位要求 = []
for i in range(len(df_boss['jobName'])):
    s = session.get(岗位详情页URL[i])
    command = s.html.find('div.job-sec-text')
    岗位要求.append(command[0].text)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 5
#       3 s = session.get(岗位详情页URL[i])
#       4 command = s.html.find('div.job-sec-text')
# ----> 5 岗位要求.append(command[0].text)
#
# IndexError: list index out of range

# %%
岗位要求
# Out:
# []

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
import random
# 设置 Chrome 为无头模式
chrome_options = Options()
chrome_options.add_argument("--headless")
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
chrome_options.add_argument(f"user-agent={user_agent}")
# 初始化 Chrome WebDriver
driver = webdriver.Chrome(options=chrome_options)

for i in range(len(岗位详情页URL)):
    url = 岗位详情页URL[i]  # 替换为你要访问的网页 URL
    driver.get(url)
    # 等待一定时间，确保 JavaScript 代码有足够的时间加载数据
    wait_time = random.randint(5,10)
    time.sleep(wait_time)  # 你可能需要根据网页加载时间进行调整
    page_content = driver.page_source
    driver.quit()
    from bs4 import BeautifulSoup
    soup = BeautifulSoup(page_content, 'html.parser')
    target_tag = soup.find('a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 s = await session.get('https://www.zhipin.com/job_detail/27a454904eafd2c51HVy3968FFFX.html?lid=6h3r5eM2hoA.search.1&securityId=3qsJFh-EfCDVZ-O1FwHF6CgiZSmJ5VnY4c77CFJc4913spQH1mxSYKrMtuwScfIjhynF_rSkW6fcJNjzh4zjuaMPlTJOkQMlhVZpF-rq4TVzbSoNBIDv_pGyxcrCtjFwgGlqmC07ot2BBWOBocAhdeRk0zX78rrTveeHHaKrG0RYzUiCQw~~&sessionId=')
#
# TypeError: object HTMLResponse can't be used in 'await' expression
