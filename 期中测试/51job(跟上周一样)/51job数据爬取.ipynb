# %% [markdown]
# # 51job有反自动化爬取，半小时能爬取一次

# %%
import pandas
from requests_html import HTMLSession
import json
import pandas as pd

# %%
import time
timestamp = time.time()
print(int(timestamp))
# Out:
# 1703348976

# %%
cities = {
    '上海':'020000',
    '北京':'010000',
    '广州':'030200',
    '深圳':'040000'
}

# %%
关键字 = input("输入职位")

# %%
关键字
# Out:
# '广告策划'

# %%
城市 = input("输入城市")

# %%
城市
# Out:
# '上海'

# %%
cities[城市]
# Out:
# '020000'

# %%
import urllib.parse
encoded_content = urllib.parse.quote(str(关键字))
print(encoded_content)
# Out:
# %E5%B9%BF%E5%91%8A%E7%AD%96%E5%88%92

# %%
url = 'https://we.51job.com/api/job/search-pc?api_key=51job&timestamp='+str(int(timestamp))+'&keyword='+str(encoded_content)+'&searchType=2&function=&industry=&jobArea='+cities[城市]+'&jobArea2=&landmark=&metro=&salary=&workYear=&degree=&companyType=&companySize=&jobType=&issueDate=&sortType=0&pageNum=1&requestId=&pageSize=20&source=1&accountId=225393392&pageCode=sou%7Csou%7Csoulb'

# %%
url
# Out:
# 'https://we.51job.com/api/job/search-pc?api_key=51job&timestamp=1703348976&keyword=%E5%B9%BF%E5%91%8A%E7%AD%96%E5%88%92&searchType=2&function=&industry=&jobArea=020000&jobArea2=&landmark=&metro=&salary=&workYear=&degree=&companyType=&companySize=&jobType=&issueDate=&sortType=0&pageNum=1&requestId=&pageSize=20&source=1&accountId=225393392&pageCode=sou%7Csou%7Csoulb'

# %%
wuyou_job_headers = {
    "Accept": "application/json, text/plain, */*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "zh-CN,zh;q=0.9",
    "Account-Id": "225393392",
    "Connection": "keep-alive",
    "Cookie": "guid=df9079b1bea9db9cb298b4eeb9d04e27; nsearch=jobarea%3D%26%7C%26ord_field%3D%26%7C%26recentSearch0%3D%26%7C%26recentSearch1%3D%26%7C%26recentSearch2%3D%26%7C%26recentSearch3%3D%26%7C%26recentSearch4%3D%26%7C%26collapse_expansion%3D; search=jobarea%7E%60010000%7C%21recentSearch0%7E%60010000%A1%FB%A1%FA000000%A1%FB%A1%FA0000%A1%FB%A1%FA00%A1%FB%A1%FA99%A1%FB%A1%FA%A1%FB%A1%FA99%A1%FB%A1%FA99%A1%FB%A1%FA99%A1%FB%A1%FA99%A1%FB%A1%FA9%A1%FB%A1%FA99%A1%FB%A1%FA%A1%FB%A1%FA0%A1%FB%A1%FA%B9%E3%B8%E6%B2%DF%BB%AE%A1%FB%A1%FA2%A1%FB%A1%FA1%7C%21recentSearch1%7E%60020000%A1%FB%A1%FA000000%A1%FB%A1%FA0000%A1%FB%A1%FA00%A1%FB%A1%FA99%A1%FB%A1%FA%A1%FB%A1%FA99%A1%FB%A1%FA99%A1%FB%A1%FA99%A1%FB%A1%FA99%A1%FB%A1%FA9%A1%FB%A1%FA99%A1%FB%A1%FA%A1%FB%A1%FA0%A1%FB%A1%FA%B9%E3%B8%E6%B2%DF%BB%AE%A1%FB%A1%FA2%A1%FB%A1%FA1%7C%21recentSearch2%7E%60040000%A1%FB
    "From-Domain": "51job_web",
    "Host": "we.51job.com",
    "Partner": "cn_bing_com",
    "Property": "%7B%22partner%22%3A%22cn_bing_com%22%2C%22webId%22%3A2%2C%22fromdomain%22%3A%2251job_web%22%2C%22frompageUrl%22%3A%22https%3A%2F%2Fwe.51job.com%2F%22%2C%22pageUrl%22%3A%22https%3A%2F%2Fwe.51job.com%2Fpc%2Fsearch%3FjobArea%3D010000%26keyword%3D%25E5%25B9%25BF%25E5%2591%258A%25E7%25AD%2596%25E5%2588%2592%26searchType%3D2%26sortType%3D0%26metro%3D%22%2C%22identityType%22%3A%22%E5%9C%A8%E6%A0%A1%E7%94%9F%22%2C%22userType%22%3A%22%E8%80%81%E7%94%A8%E6%88%B7%22%2C%22isLogin%22%3A%22%E6%98%AF%22%2C%22accountid%22%3A%22225393392%22%2C%22keywordType%22%3A%22%E7%8C%9C%E4%BD%A0%E5%96%9C%E6%AC%A2%22%7D",
    "Referer": "https://we.51job.com/pc/search?jobArea=010000&keyword=%E5%B9%BF%E5%91%8A%E7%AD%96%E5%88%92&searchType=2&sortType=0&metro=",
    "Sec-Ch-Ua": "\"Google Chrome\";v=\"119\", \"Chromium\";v=\"119\", \"Not?A_Brand\";v=\"24\"",
    "Sec-Ch-Ua-Mobile": "?0",
    "Sec-Ch-Ua-Platform": "\"Windows\"",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "Sign": "0e26dc86c90dadc780d0e42f8f01a0abbbdf5304d15bfeadd09ee3ef5c9be3fb",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
    "User-Token": "a52a0dbdd8a3ad39b515740d04b6073c656abf11",
    "Uuid": "df9079b1bea9db9cb298b4eeb9d04e27"
}

# %% [markdown]
# # 容易黑号，半小时爬取一次就可

# %%
session = HTMLSession()

r = session.get(url,headers=wuyou_job_headers)

response_data = r.json()

response_data
# Out:
# {'status': '1',
#  'message': '成功',
#  'resultbody': {'searchType': 2,
#   'engineKeywordType': 0,
#   'requestId': 'cd1e29d9f55fe22d32a3b5eaabd424ec',
#   'job': {'items': [{'property': '{"isInitiative":"是","pageCode":"sou|sou|soulb","shortPageCode":"sou|sou|soulb","searchType":"手动搜索职位","jobRank":"0","policyId":"{\\"layer_rank_v19\\":\\"1760_2\\",\\"layer_rank_v21\\":\\"1778_1\\"}","keyword":"广告策划","pageNum":"1","requestId":"cd1e29d9f55fe22d32a3b5eaabd424ec","jobType":"0"}',
#      'jobId': '149443317',
#      'jobType': '0',
#      'jobName': '海外广告策划运营',
#      'jobTags': ['1年',
#       '大专',
#       '创意策划',
#       '广告素材',
#       'tiktok',
#       'google',
#       '广告创意',
#       '视频创意',
#       '五险一金',
#       '员工旅游',
#       '出国机会',
#       '弹性工作',
#       '年终奖金'],
#      'jobNumString': '',
#      'workAreaCode': '021000',
#      'jobAreaCode': '020000',
#      'jobAreaString': '上海·浦东新区',
#      'hrefAreaPinYin': 'shanghai-pdxq',
# ...

# %%
df_wuyou = pd.json_normalize(response_data['resultbody']['job']['items'])
df_wuyou
# Out:
#                                              property      jobId jobType  \
# 0   {"isInitiative":"是","pageCode":"sou|sou|soulb"...  149443317       0
# 1   {"isInitiative":"是","pageCode":"sou|sou|soulb"...  150615927       0
# 2   {"isInitiative":"是","pageCode":"sou|sou|soulb"...  151095040       0
# 3   {"isInitiative":"是","pageCode":"sou|sou|soulb"...  146339723       0
# 4   {"isInitiative":"是","pageCode":"sou|sou|soulb"...  142771397       0
# 5   {"isInitiative":"是","pageCode":"sou|sou|soulb"...  143099686       0
# 6   {"isInitiative":"是","pageCode":"sou|sou|soulb"...  151424240       0
# 7   {"isInitiative":"是","pageCode":"sou|sou|soulb"...  148309794       0
# 8   {"isInitiative":"是","pageCode":"sou|sou|soulb"...  143276182       0
# 9   {"isInitiative":"是","pageCode":"sou|sou|soulb"...  150616009       0
# 10  {"isInitiative":"是","pageCode":"sou|sou|soulb"...  150535883       0
# 11  {"isInitiative":"是","pageCode":"sou|sou|soulb"...  137102708       0
# ...

# %%
citi_name = str(城市)
citi_name
# Out:
# '上海'

# %%
key = str(关键字)
key
# Out:
# '广告策划'

# %%
import time
time.localtime()
output_time = str(time.localtime().tm_year)+'-'\
              +str(time.localtime().tm_mon)+'-'\
             +str(time.localtime().tm_mday)
output_time
# Out:
# '2023-12-24'

# %%
import os

folder_name = f"excels/{城市}/{关键字}/{output_time}"
os.makedirs(folder_name, exist_ok=True)

# %%
df_wuyou.to_excel(f"excels/{城市}/{关键字}/{output_time}/前程无忧-{城市}-{关键字}-{output_time}.xlsx")

# %%
import pandas as pd

# %%
read_df = pd.read_excel(f"excels/{城市}/{关键字}/{output_time}/前程无忧-{城市}-{关键字}-{output_time}.xlsx")
read_df
# Out:
#     Unnamed: 0                                           property      jobId  \
# 0            0  {"isInitiative":"是","pageCode":"sou|sou|soulb"...  149443317
# 1            1  {"isInitiative":"是","pageCode":"sou|sou|soulb"...  150615927
# 2            2  {"isInitiative":"是","pageCode":"sou|sou|soulb"...  151095040
# 3            3  {"isInitiative":"是","pageCode":"sou|sou|soulb"...  146339723
# 4            4  {"isInitiative":"是","pageCode":"sou|sou|soulb"...  142771397
# 5            5  {"isInitiative":"是","pageCode":"sou|sou|soulb"...  143099686
# 6            6  {"isInitiative":"是","pageCode":"sou|sou|soulb"...  151424240
# 7            7  {"isInitiative":"是","pageCode":"sou|sou|soulb"...  148309794
# 8            8  {"isInitiative":"是","pageCode":"sou|sou|soulb"...  143276182
# 9            9  {"isInitiative":"是","pageCode":"sou|sou|soulb"...  150616009
# 10          10  {"isInitiative":"是","pageCode":"sou|sou|soulb"...  150535883
# ...

# %%
df_wuyou_job = read_df[['jobName','jobTags','jobAreaString','provideSalaryString','workYearString','degreeString','industryType1Str','companyName','companyTypeString','companySizeString','hrName','hrPosition','updateDateTime','jobHref','companyHref']]

# %%
df_wuyou_job
# Out:
#                     jobName  \
# 0                  海外广告策划运营
# 1                   品牌策划培训生
# 2                    广告创意策划
# 3   广告销售企划 应届可(150089) 日语必须
# 4        文案实习生（新闻/广告/汉语言专业）
# 5                     广告实习生
# 6             文案策划专员（2024届）
# 7                    广告文案策划
# 8            媒介实习生（广告、新闻专业）
# 9                   营销策划培训生
# 10             百联股份-营销策划管培生
# 11                     策划文案
# 12                   营销企划助理
# 13                   广告客户执行
# 14                     文案策划
# 15                 市场文案策划专员
# 16            媒介策划实习生（上海公司）
# 17                 活动策划执行经理
# 18                     文案策划
# 19                     文案策划
#
#                                               jobTags jobAreaString  \
# 0   ['1年', '大专', '创意策划', '广告素材', 'tiktok', 'google...       上海·浦东新区
# 1                                   ['在校生/应届生', '本科']            上海
# 2   ['1年', '大专', 'brief', '文案撰写', '方案', 'copybase'...        上海·普陀区
# 3   ['在校生/应届生', '大专', '五险一金', '带薪休假', '通讯补贴', '国家法...            上海
# ...

# %%
df_wuyou_job = df_wuyou_job.rename(columns={
    'jobName':'职位名称',
    'jobTags':'职位标签',
    'jobAreaString':'岗位地址',
    'provideSalaryString':'工资',
    'workYearString':'工作经验',
    'degreeString':'学历要求',
    'industryType1Str':'公司行业',
    'companyName':'公司名称',
    'companyTypeString':'公司体制',
    'companySizeString':'公司规模',
    'hrName':'招聘者名称',
    'hrPosition':'招聘者职位',
    'updateDateTime':'更新时间',
    'jobHref':'岗位详情',
    'companyHref':'公司官网',
})

# %% [markdown]
# # 尝试进入详情页爬取，抓不到数据，好像是script Ajax动态加载

# %%
# from requests_html import HTMLSession
# session = HTMLSession()

# %%
# in_headers  = {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Accept-Language": "zh-CN,zh;q=0.9",
#     "Connection": "keep-alive",
#     "From-Domain": "51job_web",
#     "Host": "cupid.51job.com",
#     "Origin": "https://jobs.51job.com",
#     "Referer": "https://jobs.51job.com/",
#     "Sec-Fetch-Dest": "empty",
#     "Sec-Fetch-Mode": "cors",
#     "Sec-Fetch-Site": "same-site",
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
#     "account-id": "225393392",
#     "sec-ch-ua": "\"Google Chrome\";v=\"119\", \"Chromium\";v=\"119\", \"Not?A_Brand\";v=\"24\"",
#     "sec-ch-ua-mobile": "?0",
#     "sec-ch-ua-platform": "\"Windows\"",
#     "sign": "56000c3e79b9c45e675542ecc5f77e5063e568717063ecc5b459e0dd4c00a57c",
#     "user-token": "8631e09ad8ed44cc0933d93833621abf6567e153",
#     "uuid": "df9079b1bea9db9cb298b4eeb9d04e27"
# }

# %%
# s = session.get(df_wuyou['jobHref'][1],headers=in_headers)
# command = s.html.find('div.tmsg')

# %% [markdown]
# # 岗位详情页

# %%
# import pandas as pd
# from requests_html2 import HTMLSession
# session = HTMLSession()

# %%
# df_wuyou['jobHref'][0]

# %%
# 技能要求 = []
# for i in range(len(df_wuyou['jobHref'])):
#     s = session.get(df_wuyou['jobHref'][i])
#     contents = s.html.find('div.job_msg')
#     if len(contents) >= 0:
#         command = contents[0].text
#         command = command.replace("\n"," ")
#         技能要求.append(command)
#     else:
#         command = '无'
#         技能要求.append(command)

# %% [markdown]
# # 输出结果

# %%
df_wuyou_job.to_excel(f"excels/{城市}/{关键字}/{output_time}/前程无忧-{城市}-{关键字}-{output_time}.xlsx")
