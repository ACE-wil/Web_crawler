# %% [markdown]
# # requests_html 异步

# %%
# import nest_asyncio
# nest_asyncio.apply()

# %%
# import asyncio
# from requests_html import AsyncHTMLSession
#
# async def fetch_data(url):
#     session = AsyncHTMLSession()
#     response = await session.get(url)
#     await response.html.arender()
#     await asyncio.sleep(15)
#
#     elements = response.html.find('div.job-sec-text')  # 替换为你的选择器
#     text_content = [element.text for element in elements]
#
#     return text_content
#
# async def main():
#     url = 'https://www.zhipin.com/job_detail/68451cc9884ccf761HZ42dW8ElJT.html?lid=6ChDThUbzno.search.3&securityId=b6JDOu6PlMjGM-_1_plr33F9r9kSRyvoCkZ6l2hfmiaje5gLAJMipfEB_zrSytNUWGJQCX7AcxPC5twGU7DvRqq8BmuzA03NpYmzLRvoWBEgFZwCJhnimVtZD2VUqvuUG52RCR1mQSpqWI3AJ4HOpCaNFj5imIY_oxqj4UweNH1iAg~~&sessionId='  # 替换为你要访问的网页 URL
#     result = await fetch_data(url)
#     return result
#
# # 创建事件循环并运行异步函数
# loop = asyncio.get_event_loop()
# result = loop.run_until_complete(main())
# result
# Out:
# []

# %%
# import asyncio
# from requests_html import AsyncHTMLSession
#
# async def fetch_data(url):
#     session = AsyncHTMLSession()
#     response = await session.get(url)
#     await response.html.arender()
#
#     # 输出整个页面的 HTML 内容
#     print(response.text)
#
#     return response
#
# async def main():
#     url = 'https://www.zhipin.com/job_detail/68451cc9884ccf761HZ42dW8ElJT.html?lid=6ChDThUbzno.search.3&securityId=b6JDOu6PlMjGM-_1_plr33F9r9kSRyvoCkZ6l2hfmiaje5gLAJMipfEB_zrSytNUWGJQCX7AcxPC5twGU7DvRqq8BmuzA03NpYmzLRvoWBEgFZwCJhnimVtZD2VUqvuUG52RCR1mQSpqWI3AJ4HOpCaNFj5imIY_oxqj4UweNH1iAg~~&sessionId='  # 替换为你要访问的网页 URL
#     result = await fetch_data(url)
#     return result
#
# # 创建事件循环并运行异步函数
# loop = asyncio.get_event_loop()
# result = loop.run_until_complete(main())
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="utf-8" />
#         <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
#         <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />
#         <title>è¯·ç¨å</title>
#         <style>
#             html,
#             body {
#                 margin: 0;
#                 width: 100%;
#                 height: 100%;
#             }
#             @keyframes bossLoading {
#                 0% {
#                     transform: translate3d(0, 0, 0);
#                 }
#                 50% {
#                     transform: translate3d(0, -10px, 0);
#                 }
#             }
#             .data-tips {
#                 text-align: center;
#                 height: 100%;
#                 position: relative;
#                 background: #fff;
#                 top: 50%;
#                 margin-top: -37px;
#             }
# ...

# %% [markdown]
# # Selenium 和 Webdriver使用谷歌爬取

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
import random
# 设置 Chrome 为无头模式
chrome_options = Options()
chrome_options.add_argument("--headless")
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
chrome_options.add_argument(f"user-agent={user_agent}")
# 初始化 Chrome WebDriver
driver = webdriver.Chrome(options=chrome_options)

# 目标网页 URL
url = 'https://jobs.51job.com/beijing-cyq/151690627.html?s=sou_sou_soulb&t=0_0&req=d3310cd415ac789e4f3a5075ca48ef9a'  # 替换为你要访问的网页 URL

# 访问网页
driver.get(url)

# 等待一定时间，确保 JavaScript 代码有足够的时间加载数据
# wait_time = random.randint(3,4)
time.sleep(10)  # 你可能需要根据网页加载时间进行调整

# 获取网页内容
page_content = driver.page_source

# 关闭 WebDriver
driver.quit()

# 输出网页内容
print(page_content)
# Out:
# <html><head>
#         <meta charset="UTF-8">
#         <title>滑动验证页面</title>
#       <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <style type="text/css">
#             html, body, div, span, p{
#                 margin:0;
#                 padding:0;
#                 border:0;
#                 outline:0;
#                 font-size:100%;
#                 vertical-align:baseline;
#                 background:transparent;
#             }
#             body{
#                 background: #fff;
#             }
#         </style>
# ...

# %%
with open('code.txt','w',encoding="UTF-8") as file:
    file.write(page_content)

# %%
import re
url_pattern = r"url: '(.*?)'"
match = re.search(url_pattern, page_content)

# 检查是否找到匹配项并提取URL
extracted_url = match.group(1) if match else None

print(extracted_url)
# Out:
# http://jobs.51job.com/beijing-cyq/151690627.html?s=sou_sou_soulb&t=0_0&req=d3310cd415ac789e4f3a5075ca48ef9a

# %%
from requests_html import AsyncHTMLSession
asession = AsyncHTMLSession()
r = await asession.get('https://jobs.51job.com/beijing-cyq/151690627.html?s=sou_sou_soulb&t=0_0&req=d3310cd415ac789e4f3a5075ca48ef9a')

# %%
r.content
# Out:
# b'    <!DOCTYPE html>\n    <html>\n    <head>\n        <meta charset="UTF-8">\n        <title>\xe6\xbb\x91\xe5\x8a\xa8\xe9\xaa\x8c\xe8\xaf\x81\xe9\xa1\xb5\xe9\x9d\xa2</title>\n      <meta name="viewport" content="width=device-width, initial-scale=1.0" />\n        <style type="text/css">\n            html, body, div, span, p{\n                margin:0;\n                padding:0;\n                border:0;\n                outline:0;\n                font-size:100%;\n                vertical-align:baseline;\n                background:transparent;\n            }\n            body{\n                background: #fff;\n            }\n        </style>\n        <script type="text/javascript">\n            if (window.console === undefined){\n                console = {};\n                console.log = function(){};\n            };\n\n            window._waf_is_mobile = false;\n\n            (function(a) {\n                if (/(android|bb\\d+|meego).+mobile|avantgo|bada\\/|blackberry|blazer
# ...

# %%
find_command = r.html.find('div.job_msg')

# %%
command = find_command[0].text
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 command = find_command[0].text
#
# IndexError: list index out of range

# %%
command = command.replace('\n',' ')
command
# Out:
# '岗位职责: 1、市场调研及报告输出 2、策略发想及方案撰写 3、项目把控及创作沟通协调 任职要求: 1、本科及以上学历，广告、市场营销类相关专业优先考虑 2、良好的逻辑思维及表达沟通能力，文字功底较好，团队协作能力强 3、具备广告营销、社会化营销相关项目实习经历优先考虑 职能类别：文案/策划 关键字：市场营销市场调研广告方案撰写广告营销社会化营销报告输出项目把控'

# %%
from requests_html import HTMLSession
session = HTMLSession()
payload = {
    "api_key": "51job",
    "timestamp": "1701501777",
    "jobId": "151690627",
    "pageNum": "1",
    "pageSize": "20",
    "ipcity__1361": "eqfxRDBQD=0=MDmqGNDQurLF9m8wDx7KQx"
}
headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "zh-CN,zh;q=0.9",
    "Connection": "keep-alive",
    "From-Domain": "51job_web",
    "Host": "cupid.51job.com",
    "Origin": "https://jobs.51job.com",
    "Referer": "https://jobs.51job.com/",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-site",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
    "account-id": "225393392",
    "sec-ch-ua": "\"Google Chrome\";v=\"119\", \"Chromium\";v=\"119\", \"Not?A_Brand\";v=\"24\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sign": "9d74bb7dbcc1297b10ee45db305b7f2cb979f30819f44135a82a33cb1ea31e76",
    "user-token": "a52a0dbdd8a3ad39b515740d04b6073c656abf11",
    "uuid": "df9079b1bea9db9cb298b4eeb9d04e27"
}
r = session.get('https://cupid.51job.com/open/noauth/jobs/same?api_key=51job&timestamp=1701501507&jobId=151690627&pageNum=1&pageSize=20&ipcity__1361=eqfxRDBQD%3D0%3DMDmqGNDQurLF9m8wDx7KQx',headers=headers,data=payload)

# %%
r.text
# Out:
# '{"status":"1","message":"成功","resultbody":{"items":[{"property":"{\\"isInitiative\\":\\"是\\",\\"searchType\\":\\"自动搜索职位\\",\\"jobRank\\":\\"0\\",\\"policyId\\":\\"{\\\\\\"job_rec_rank_02\\\\\\":\\\\\\"1696_1\\\\\\",\\\\\\"job_rec_rank_04\\\\\\":\\\\\\"1705_1\\\\\\"}\\",\\"keyword\\":\\"\\",\\"pageNum\\":\\"1\\",\\"requestId\\":\\"69238be1f9c23f0b7bf922e55981335a\\",\\"jobType\\":\\"0\\"}","jobId":"151971189","jobType":"0","jobName":"创意文案策划","jobTags":["1年","本科"],"jobNumString":"","workAreaCode":"010500","jobAreaCode":"010000","jobAreaString":"北京·朝阳区","hrefAreaPinYin":"beijing-cyq","jobAreaLevelDetail":{"provinceString":"北京","cityString":"北京","districtString":"朝阳区","landMarkString":""},"provideSalaryString":"4-8千","issueDateString":"2023-11-28 04:19:29","confirmDateString":"2023-11-13 10:32:41","workYear":"3","workYearString":"1年","degreeString":"本科","industryType1":"48","industryType2":"","industryType1Str":"公关/市场推广/会展","industryType2Str":"","funcType1Code":"4207","funcType2Code":""
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, 'html.parser')

# %%
command = soup.select_one('.job-sec-text')

# %%
r.html.find('div.job_msg')
# Out:
# []

# %%
# with open('command_html.txt','w',encoding="utf-8") as file:
#     file.write(page_content)

# %%
# with open("command_html.txt", "r", encoding="utf-8") as file:
#     # 读取文件内容
#     file_content = file.read()

# %%
# file_content
# Out:
# '<html><head>\n    <meta charset="utf-8">\n    <title>「广告策划（实习生、应届生、有经验者均可）招聘」_安思一招聘-BOSS直聘</title>\n    <meta name="keywords" content="广告策划（实习生、应届生、有经验者均可）,广告策划（实习生、应届生、有经验者均可）招聘,安思一广告策划（实习生、应届生、有经验者均可）招聘">\n    <meta name="description" content="安思一广告策划（实习生、应届生、有经验者均可）招聘，薪资：6-11K，地点：北京，要求：经验不限，学历：本科，福利：餐补、五险一金，Hr刚刚在线，随时随地直接开聊。">\n    <link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.zhipin.com/job_detail/27a454904eafd2c51HVy3968FFFX.html">\n    <link rel="canonical" href="https://www.zhipin.com/job_detail/27a454904eafd2c51HVy3968FFFX.html">\n    <meta name="applicable-device" content="pc">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n    <link href="https://static.zhipin.com/zhipin-geek/v688/web/geek/css/main.css" type="text/css" rel="stylesheet">\n    <script src="//hm.baidu.com/hm.js?194df3105ad7148dcf2b98a91b5e727a"></script><script src="https://static.zhipin.com/library/js/analytics/ka.zhipin.min.js"></script><script type="t
# ...
